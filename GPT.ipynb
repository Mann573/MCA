# %% [markdown]
# ### 1

# %%
# Implement a simple Neural Network using Keras to classify handwritten digits from the MNIST dataset. Achieve a minimum accuracy of 95% on the test set.

# - Load the MNIST dataset using Keras’ datasets module.
# - Preprocess the data by normalizing the pixel values.
# - Define a simple Neural Network architecture with at least two hidden layers.
# - Compile the model with a suitable optimizer and loss function.
# - Train the model on the training set and evaluate its performance on the test set.

import numpy as np
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical

# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize the data (pixel values between 0 and 1)
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# One-hot encode the labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Define the Neural Network architecture
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=10, batch_size=32, validation_split=0.2)

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f"Test accuracy: {test_accuracy * 100:.2f}%")
# Out:
# C:\Users\MANN\anaconda3\envs\myenv\lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8667 - loss: 0.4708 - val_accuracy: 0.9570 - val_loss: 0.1412
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9633 - loss: 0.1230 - val_accuracy: 0.9672 - val_loss: 0.1112
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9772 - loss: 0.0757 - val_accuracy: 0.9682 - val_loss: 0.1010
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9843 - loss: 0.0518 - val_accuracy: 0.9692 - val_loss: 0.1139
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9860 - loss: 0.0440 - val_accuracy: 0.9736 - val_loss: 0.0968
# Epoch 6/10
# ...

# %% [markdown]
# ### 2

# %%
# Use TensorFlow to visualize the weights and biases of a trained Neural Network model on the MNIST dataset.

# - Load the trained Neural Network model.
# - Use TensorFlow’s tf.keras.layers module to extract the weights and biases of the model.
# - Use a visualization library (e.g., Matplotlib, Seaborn) to plot the weights and biases.

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical

# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize the data (pixel values between 0 and 1)
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# One-hot encode the labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Define the Neural Network architecture
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=10, batch_size=32, validation_split=0.2)

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f"Test accuracy: {test_accuracy * 100:.2f}%")

# Visualizing weights and biases
# Extract weights and biases of the first dense layer
weights, biases = model.layers[1].get_weights()

# Visualize weights
plt.figure(figsize=(10, 8))
sns.heatmap(weights, cmap='coolwarm', center=0)
plt.title("Visualization of Weights (Dense Layer 1)")
plt.xlabel("Neurons")
plt.ylabel("Input Features")
plt.tight_layout()
plt.show()

# Visualize biases
plt.figure(figsize=(8, 2))
plt.bar(range(len(biases)), biases)
plt.title("Visualization of Biases (Dense Layer 1)")
plt.xlabel("Neurons")
plt.ylabel("Bias Values")
plt.show()
# Out:
# Epoch 1/10
# C:\Users\MANN\anaconda3\envs\myenv\lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8593 - loss: 0.4743 - val_accuracy: 0.9598 - val_loss: 0.1365
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9640 - loss: 0.1175 - val_accuracy: 0.9693 - val_loss: 0.1007
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9772 - loss: 0.0748 - val_accuracy: 0.9689 - val_loss: 0.1022
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9834 - loss: 0.0548 - val_accuracy: 0.9723 - val_loss: 0.0934
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9876 - loss: 0.0418 - val_accuracy: 0.9758 - val_loss: 0.0897
# Epoch 6/10
# ...

# %% [markdown]
# ### 3

# %%
# Implement a Convolutional Neural Network (CNN) using Keras to classify handwritten digits from the MNIST dataset. Achieve a minimum accuracy of 98% on the test set.

# - Load the MNIST dataset using Keras’ datasets module.
# - Preprocess the data by normalizing the pixel values.
# - Define a CNN architecture with at least two convolutional layers and two fully connected layers.
# - Compile the model with a suitable optimizer and loss function.
# - Train the model on the training set and evaluate its performance on the test set.

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.utils import to_categorical

# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize the data (pixel values between 0 and 1)
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# Reshape data to include channel dimension
x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

# One-hot encode the labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Define the CNN architecture
model = Sequential([
    Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(64, kernel_size=(3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=10, batch_size=32, validation_split=0.2)

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f"Test accuracy: {test_accuracy * 100:.2f}%")

# Visualizing weights and biases (optional)
# Extract weights and biases of the first convolutional layer
weights, biases = model.layers[0].get_weights()

# Visualize weights
fig, axes = plt.subplots(4, 8, figsize=(12, 6))
for i, ax in enumerate(axes.flat):
    if i < weights.shape[-1]:
        ax.imshow(weights[:, :, 0, i], cmap='gray')
        ax.axis('off')
plt.suptitle("Visualization of Filters (Conv Layer 1)")
plt.show()

# Visualize biases
plt.figure(figsize=(8, 2))
plt.bar(range(len(biases)), biases)
plt.title("Visualization of Biases (Conv Layer 1)")
plt.xlabel("Filters")
plt.ylabel("Bias Values")
plt.show()
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - accuracy: 0.8939 - loss: 0.3408 - val_accuracy: 0.9831 - val_loss: 0.0576
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.9846 - loss: 0.0503 - val_accuracy: 0.9853 - val_loss: 0.0491
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.9897 - loss: 0.0317 - val_accuracy: 0.9845 - val_loss: 0.0504
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.9926 - loss: 0.0228 - val_accuracy: 0.9883 - val_loss: 0.0377
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.9947 - loss: 0.0165 - val_accuracy: 0.9869 - val_loss: 0.0507
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 13s 9ms/step - accuracy: 0.9961 - loss: 0.0130 - val_accuracy: 0.9882 - val_loss: 0.0413
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.9963 - loss: 0.0106 - val_accuracy: 0.9893 - val_loss: 0.0466
# Epoch 8/10
# ...

# %% [markdown]
# ### 4

# %%
# Use PyTorch to implement data augmentation techniques (e.g., rotation, scaling, flipping) on the MNIST dataset.
# - Load the MNIST dataset using PyTorch’s torchvision module.
# - Define a data augmentation pipeline using PyTorch’s torchvision.transforms module.
# - Apply the data augmentation pipeline to the training set. 

import numpy as np
import matplotlib.pyplot as plt
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.optim as optim
import torch

# Define data augmentation pipeline
transform = transforms.Compose([
    transforms.RandomRotation(30),  # Random rotation up to 30 degrees
    transforms.RandomResizedCrop(28, scale=(0.8, 1.0)),  # Random scaling
    transforms.RandomHorizontalFlip(),  # Random horizontal flip
    transforms.ToTensor(),  # Convert to tensor
    transforms.Normalize((0.5,), (0.5,))  # Normalize to [-1, 1]
])

# Load the MNIST dataset with data augmentation for the training set
train_dataset = datasets.MNIST(root='./data', train=True, transform=transform, download=True)
test_dataset = datasets.MNIST(root='./data', train=False, transform=transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
]))

# Data loaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# Check for GPU availability
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Define a simple CNN model
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3)
        self.fc1 = nn.Linear(64 * 5 * 5, 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, 10)

    def forward(self, x):
        x = self.pool(torch.relu(self.conv1(x)))
        x = self.pool(torch.relu(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# Instantiate the model, define the loss function and optimizer
model = CNN().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Training loop
epochs = 5
for epoch in range(epochs):
    model.train()
    running_loss = 0.0
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

    print(f"Epoch {epoch + 1}/{epochs}, Loss: {running_loss / len(train_loader)}")

# Evaluation loop
model.eval()
correct = 0
total = 0
with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f"Test Accuracy: {100 * correct / total:.2f}%")

# Visualize some augmented images
examples = iter(train_loader)
example_data, example_targets = examples.next()

fig, axes = plt.subplots(1, 6, figsize=(15, 5))
for i in range(6):
    axes[i].imshow(example_data[i][0].cpu().numpy(), cmap='gray')
    axes[i].axis('off')
plt.suptitle("Augmented MNIST Images")
plt.show()
# Out:
# Using device: cpu
# Epoch 1/5, Loss: 0.48857544247110685
# Epoch 2/5, Loss: 0.2047568458586931
# Epoch 3/5, Loss: 0.15601389480804403
# Epoch 4/5, Loss: 0.13817273863367735
# Epoch 5/5, Loss: 0.12447490368994574
# Test Accuracy: 97.74%
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 96
#      94 # Visualize some augmented images
#      95 examples = iter(train_loader)
# ---> 96 example_data, example_targets = examples.next()
#      98 fig, axes = plt.subplots(1, 6, figsize=(15, 5))
#      99 for i in range(6):
#
# AttributeError: '_SingleProcessDataLoaderIter' object has no attribute 'next'

# %% [markdown]
# ### 5

# %%
# Implement a Recurrent Neural Network (RNN) using Keras to classify handwritten digits from the MNIST dataset. Achieve a minimum accuracy of 90% on the test set.

# - Load the MNIST dataset using Keras’ datasets module.
# - Preprocess the data by normalizing the pixel values.
# - Define an RNN architecture with at least one recurrent layer and two fully connected layers.
# - Compile the model with a suitable optimizer and loss function.
# - Train the model on the training set and evaluate its performance on the test set.

import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense, Flatten
from tensorflow.keras.utils import to_categorical

# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize the data (pixel values between 0 and 1)
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# One-hot encode the labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Define the RNN architecture
model = Sequential([
    SimpleRNN(128, activation='relu', input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=10, batch_size=32, validation_split=0.2)

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f"Test accuracy: {test_accuracy * 100:.2f}%")

# Visualizing some predictions
predictions = model.predict(x_test[:10])
fig, axes = plt.subplots(1, 10, figsize=(15, 5))
for i in range(10):
    axes[i].imshow(x_test[i], cmap='gray')
    axes[i].set_title(f"Pred: {np.argmax(predictions[i])}")
    axes[i].axis('off')
plt.suptitle("Sample Predictions")
plt.show()
# Out:
# C:\Users\MANN\anaconda3\envs\myenv\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.6985 - loss: 0.8608 - val_accuracy: 0.9290 - val_loss: 0.2459
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9341 - loss: 0.2296 - val_accuracy: 0.9444 - val_loss: 0.1914
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9435 - loss: 0.1997 - val_accuracy: 0.9563 - val_loss: 0.1567
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9529 - loss: 0.1635 - val_accuracy: 0.9562 - val_loss: 0.1464
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9581 - loss: 0.1511 - val_accuracy: 0.9658 - val_loss: 0.1169
# Epoch 6/10
# ...

# %% [markdown]
# ### 6

# %%
# Use TensorFlow to visualize the activations of a trained RNN model on the MNIST dataset.

# - Load the trained RNN model.
# - Use TensorFlow's tf.keras.layers module to extract the activations of the model.
# - Use a visualization library (e.g., Matplotlib, Seaborn) to plot the activations.
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import SimpleRNN, Dense, Flatten, Input
from tensorflow.keras.utils import to_categorical
import seaborn as sns

# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize the data (pixel values between 0 and 1)
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# One-hot encode the labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Define the RNN architecture
inputs = Input(shape=(28, 28))
x = SimpleRNN(128, activation='relu', return_sequences=True)(inputs)
x = SimpleRNN(64, activation='relu')(x)
x = Dense(128, activation='relu')(x)
x = Dense(64, activation='relu')(x)
outputs = Dense(10, activation='softmax')(x)
model = Model(inputs=inputs, outputs=outputs)

# Compile the model
model.compile(optimizer='adam', 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=10, batch_size=32, validation_split=0.2)

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f"Test accuracy: {test_accuracy * 100:.2f}%")

# Visualizing activations
layer_outputs = [layer.output for layer in model.layers if 'rnn' in layer.name or 'dense' in layer.name]
activation_model = Model(inputs=model.input, outputs=layer_outputs)
sample_input = x_test[:1]  # Use a single test sample
activations = activation_model.predict(sample_input)

# Plot activations
for i, activation in enumerate(activations):
    if len(activation.shape) == 3:  # For RNN layers
        plt.figure(figsize=(10, 5))
        sns.heatmap(activation[0].T, cmap='viridis')
        plt.title(f"Layer {i + 1} Activations (RNN)")
        plt.xlabel("Time Step")
        plt.ylabel("Units")
        plt.show()
    elif len(activation.shape) == 2:  # For Dense layers
        plt.figure(figsize=(8, 4))
        plt.bar(range(activation.shape[1]), activation[0])
        plt.title(f"Layer {i + 1} Activations (Dense)")
        plt.xlabel("Units")
        plt.ylabel("Activation Value")
        plt.show()

# Visualizing some predictions
predictions = model.predict(x_test[:10])
fig, axes = plt.subplots(1, 10, figsize=(15, 5))
for i in range(10):
    axes[i].imshow(x_test[i], cmap='gray')
    axes[i].set_title(f"Pred: {np.argmax(predictions[i])}")
    axes[i].axis('off')
plt.suptitle("Sample Predictions")
plt.show()
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 15s 8ms/step - accuracy: 0.7316 - loss: 0.7694 - val_accuracy: 0.9530 - val_loss: 0.1681
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.9461 - loss: 0.1835 - val_accuracy: 0.9541 - val_loss: 0.1568
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.9540 - loss: 0.1567 - val_accuracy: 0.9663 - val_loss: 0.1216
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.9670 - loss: 0.1213 - val_accuracy: 0.9525 - val_loss: 0.1846
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9665 - loss: 0.1154 - val_accuracy: 0.9656 - val_loss: 0.1492
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.9716 - loss: 0.1046 - val_accuracy: 0.9687 - val_loss: 0.1196
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.9721 - loss: 0.1026 - val_accuracy: 0.9691 - val_loss: 0.1267
# Epoch 8/10
# ...

# %% [markdown]
# ### 7

# %%
# Implement a CNN model using Keras to classify handwritten digits from the MNIST dataset. Achieve a minimum accuracy of 95% on the test set.

import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.utils import to_categorical

# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Reshape the data to include channel dimension
x_train = x_train.reshape(-1, 28, 28, 1).astype('float32') / 255.0
x_test = x_test.reshape(-1, 28, 28, 1).astype('float32') / 255.0

# One-hot encode the labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Define the CNN architecture
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=10, batch_size=32, validation_split=0.2)

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f"Test accuracy: {test_accuracy * 100:.2f}%")

# Visualizing some predictions
predictions = model.predict(x_test[:10])
fig, axes = plt.subplots(1, 10, figsize=(15, 5))
for i in range(10):
    axes[i].imshow(x_test[i].reshape(28, 28), cmap='gray')
    axes[i].set_title(f"Pred: {np.argmax(predictions[i])}")
    axes[i].axis('off')
plt.suptitle("Sample Predictions")
plt.show()

# %% [markdown]
# ### 8

# %%
# Implement a CNN model using Keras to classify handwritten digits from the MNIST dataset. Achieve a minimum accuracy of 95% on the test set.

# - Load the MNIST dataset using Keras' datasets module.
# - Preprocess the data by normalizing the pixel values.
# - Define a CNN architecture using Keras' Sequential API:
#     - Input layer with 28x28 images
#     - Convolutional layer with 32 filters and ReLU activation
#     - Max pooling layer with 2x2 pool size
#     - Convolutional layer with 64 filters and ReLU activation
#     - Max pooling layer with 2x2 pool size
#     - Flatten layer
#     - Dense layer with 128 neurons and ReLU activation
#     - Output layer with 10 neurons and softmax activation
# - Compile the model with a suitable optimizer (e.g., Adam) and loss function (e.g., categorical cross-entropy).
# - Train the model on the training set and evaluate its performance on the test set.

import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Preprocess the data
x_train = x_train.astype('float32') / 255.0  # Normalize pixel values to [0, 1]
x_test = x_test.astype('float32') / 255.0

# Reshape the data to include the channel dimension (grayscale images)
x_train = x_train.reshape((x_train.shape[0], 28, 28, 1))
x_test = x_test.reshape((x_test.shape[0], 28, 28, 1))

# One-hot encode the labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Define the CNN model using Keras Sequential API
model = models.Sequential()

# Input layer and first convolutional layer
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(layers.MaxPooling2D((2, 2)))

# Second convolutional layer
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

# Flatten the output of the last pooling layer
model.add(layers.Flatten())

# Dense hidden layer
model.add(layers.Dense(128, activation='relu'))

# Output layer with 10 classes (digits 0-9)
model.add(layers.Dense(10, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=5, batch_size=64, validation_split=0.1)

# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f'Test accuracy: {test_acc * 100:.2f}%')
# Out:
# Epoch 1/5
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.8883 - loss: 0.3811 - val_accuracy: 0.9843 - val_loss: 0.0552
# Epoch 2/5
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 12s 14ms/step - accuracy: 0.9832 - loss: 0.0520 - val_accuracy: 0.9852 - val_loss: 0.0468
# Epoch 3/5
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step - accuracy: 0.9895 - loss: 0.0349 - val_accuracy: 0.9887 - val_loss: 0.0379
# Epoch 4/5
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step - accuracy: 0.9926 - loss: 0.0232 - val_accuracy: 0.9912 - val_loss: 0.0315
# Epoch 5/5
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step - accuracy: 0.9948 - loss: 0.0162 - val_accuracy: 0.9908 - val_loss: 0.0355
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9885 - loss: 0.0385
# Test accuracy: 99.15%
